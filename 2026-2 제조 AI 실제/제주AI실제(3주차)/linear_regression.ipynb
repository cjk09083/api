# %% [markdown]
# # TensorFlow를 활용한 선형회귀 실습
#
# 이 노트북에서는 TensorFlow를 사용하여 간단한 선형회귀 문제를 풀어봅니다.
#
# ## 주요 단계
# 1. 데이터 생성 (y = 3x + 2 + 잡음)
# 2. 모델 정의 (Dense Layer)
# 3. 손실 함수 및 최적화 방법 설정
# 4. 학습 진행 및 시각화

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.21.0

# %% [markdown]
# ## 1. 데이터 생성

# %%
# y = 3x + 2 + noise
n_samples = 5
X = np.linspace(-5, 5, n_samples)
y = 3 * X + 2 + np.random.normal(0, 1, n_samples)*20

plt.scatter(X, y)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Generated Data")
plt.show()
# Out:
# /var/folders/76/lsnx8b5j45j73b66c6fjtg780000gn/T/ipykernel_24070/3034282863.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## 2. 모델 정의

# %%
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 3. 모델 컴파일
# - 손실 함수: MSE (Mean Squared Error)
# - 최적화 방법: SGD (Stochastic Gradient Descent)

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
              loss='mse')

# %% [markdown]
# ## 4. 모델 학습

# %%
history = model.fit(X, y, epochs=200, verbose=2)

plt.plot(history.history['loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss')
plt.show()
# Out:
# Epoch 1/200
# 1/1 - 0s - 75ms/step - loss: 1106.4231
# Epoch 2/200
# 1/1 - 0s - 13ms/step - loss: 761.0509
# Epoch 3/200
# 1/1 - 0s - 12ms/step - loss: 566.5001
# Epoch 4/200
# 1/1 - 0s - 12ms/step - loss: 456.7975
# Epoch 5/200
# 1/1 - 0s - 12ms/step - loss: 394.8327
# Epoch 6/200
# 1/1 - 0s - 13ms/step - loss: 359.7304
# Epoch 7/200
# 1/1 - 0s - 13ms/step - loss: 339.7481
# Epoch 8/200
# 1/1 - 0s - 14ms/step - loss: 328.2802
# Epoch 9/200
# 1/1 - 0s - 12ms/step - loss: 321.6107
# Epoch 10/200
# 1/1 - 0s - 13ms/step - loss: 317.6490
# Epoch 11/200
# 1/1 - 0s - 13ms/step - loss: 315.2187
# Epoch 12/200
# 1/1 - 0s - 13ms/step - loss: 313.6578
# Epoch 13/200
# 1/1 - 0s - 12ms/step - loss: 312.5937
# Epoch 14/200
# 1/1 - 0s - 13ms/step - loss: 311.8163
# Epoch 15/200
# 1/1 - 0s - 13ms/step - loss: 311.2073
# Epoch 16/200
# 1/1 - 0s - 12ms/step - loss: 310.6998
# Epoch 17/200
# 1/1 - 0s - 12ms/step - loss: 310.2560
# Epoch 18/200
# 1/1 - 0s - 13ms/step - loss: 309.8542
# Epoch 19/200
# 1/1 - 0s - 12ms/step - loss: 309.4822
# Epoch 20/200
# 1/1 - 0s - 13ms/step - loss: 309.1326
# Epoch 21/200
# 1/1 - 0s - 13ms/step - loss: 308.8012
# Epoch 22/200
# 1/1 - 0s - 12ms/step - loss: 308.4854
# Epoch 23/200
# 1/1 - 0s - 12ms/step - loss: 308.1834
# Epoch 24/200
# 1/1 - 0s - 13ms/step - loss: 307.8943
# Epoch 142/200
# 1/1 - 0s - 13ms/step - loss: 300.9651
# Epoch 143/200
# 1/1 - 0s - 12ms/step - loss: 300.9628
# Epoch 144/200
# 1/1 - 0s - 13ms/step - loss: 300.9605
# Epoch 145/200
# 1/1 - 0s - 12ms/step - loss: 300.9584
# Epoch 146/200
# 1/1 - 0s - 13ms/step - loss: 300.9563
# Epoch 147/200
# 1/1 - 0s - 13ms/step - loss: 300.9543
# Epoch 148/200
# 1/1 - 0s - 12ms/step - loss: 300.9523
# Epoch 149/200
# 1/1 - 0s - 13ms/step - loss: 300.9505
# Epoch 150/200
# 1/1 - 0s - 13ms/step - loss: 300.9487
# Epoch 151/200
# 1/1 - 0s - 12ms/step - loss: 300.9470
# Epoch 152/200
# 1/1 - 0s - 13ms/step - loss: 300.9454
# Epoch 153/200
# 1/1 - 0s - 12ms/step - loss: 300.9438
# Epoch 154/200
# 1/1 - 0s - 12ms/step - loss: 300.9423
# Epoch 155/200
# 1/1 - 0s - 12ms/step - loss: 300.9409
# Epoch 156/200
# 1/1 - 0s - 12ms/step - loss: 300.9395
# Epoch 157/200
# 1/1 - 0s - 13ms/step - loss: 300.9381
# Epoch 158/200
# 1/1 - 0s - 12ms/step - loss: 300.9369
# Epoch 159/200
# 1/1 - 0s - 12ms/step - loss: 300.9356
# Epoch 160/200
# 1/1 - 0s - 12ms/step - loss: 300.9344
# Epoch 161/200
# 1/1 - 0s - 13ms/step - loss: 300.9333
# Epoch 162/200
# 1/1 - 0s - 12ms/step - loss: 300.9322
# Epoch 163/200
# 1/1 - 0s - 12ms/step - loss: 300.9312
# Epoch 164/200
# 1/1 - 0s - 12ms/step - loss: 300.9301
# Epoch 165/200
# 1/1 - 0s - 13ms/step - loss: 300.9292
# Epoch 166/200
# 1/1 - 0s - 13ms/step - loss: 300.9282
# Epoch 167/200
# 1/1 - 0s - 12ms/step - loss: 300.9274
# Epoch 168/200
# 1/1 - 0s - 13ms/step - loss: 300.9265
# Epoch 169/200
# 1/1 - 0s - 12ms/step - loss: 300.9257
# Epoch 170/200
# 1/1 - 0s - 12ms/step - loss: 300.9249
# Epoch 171/200
# 1/1 - 0s - 13ms/step - loss: 300.9242
# Epoch 172/200
# 1/1 - 0s - 12ms/step - loss: 300.9234
# Epoch 173/200
# 1/1 - 0s - 12ms/step - loss: 300.9227
# Epoch 174/200
# 1/1 - 0s - 12ms/step - loss: 300.9220
# Epoch 175/200
# 1/1 - 0s - 13ms/step - loss: 300.9214
# Epoch 176/200
# 1/1 - 0s - 12ms/step - loss: 300.9208
# Epoch 177/200
# 1/1 - 0s - 12ms/step - loss: 300.9202
# Epoch 178/200
# 1/1 - 0s - 12ms/step - loss: 300.9196
# Epoch 179/200
# 1/1 - 0s - 12ms/step - loss: 300.9190
# Epoch 180/200
# 1/1 - 0s - 13ms/step - loss: 300.9185
# Epoch 181/200
# 1/1 - 0s - 12ms/step - loss: 300.9180
# Epoch 182/200
# 1/1 - 0s - 11ms/step - loss: 300.9175
# Epoch 183/200
# 1/1 - 0s - 12ms/step - loss: 300.9171
# Epoch 184/200
# 1/1 - 0s - 12ms/step - loss: 300.9166
# Epoch 185/200
# 1/1 - 0s - 12ms/step - loss: 300.9162
# Epoch 186/200
# 1/1 - 0s - 13ms/step - loss: 300.9158
# Epoch 187/200
# 1/1 - 0s - 13ms/step - loss: 300.9154
# Epoch 188/200
# 1/1 - 0s - 12ms/step - loss: 300.9150
# Epoch 189/200
# 1/1 - 0s - 13ms/step - loss: 300.9146
# Epoch 190/200
# 1/1 - 0s - 13ms/step - loss: 300.9143
# Epoch 191/200
# 1/1 - 0s - 12ms/step - loss: 300.9139
# Epoch 192/200
# 1/1 - 0s - 12ms/step - loss: 300.9136
# Epoch 193/200
# 1/1 - 0s - 12ms/step - loss: 300.9133
# Epoch 194/200
# 1/1 - 0s - 12ms/step - loss: 300.9130
# Epoch 195/200
# 1/1 - 0s - 11ms/step - loss: 300.9127
# Epoch 196/200
# 1/1 - 0s - 13ms/step - loss: 300.9124
# Epoch 197/200
# 1/1 - 0s - 12ms/step - loss: 300.9122
# Epoch 198/200
# 1/1 - 0s - 12ms/step - loss: 300.9119
# Epoch 199/200
# 1/1 - 0s - 13ms/step - loss: 300.9117
# Epoch 200/200
# 1/1 - 0s - 12ms/step - loss: 300.9114
# /var/folders/76/lsnx8b5j45j73b66c6fjtg780000gn/T/ipykernel_24070/4188173742.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## 5. 결과 확인

# %%
W, b = model.layers[0].get_weights()
print(f"학습된 기울기 W: {W[0][0]:.3f}, 절편 b: {b[0]:.3f}")

y_pred = model.predict(X)

plt.scatter(X, y, label='Data')
plt.plot(X, y_pred, color='red', label='Fitted Line')
plt.legend()
plt.show()
# Out:
# 학습된 기울기 W: 7.280, 절편 b: -4.133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# /var/folders/76/lsnx8b5j45j73b66c6fjtg780000gn/T/ipykernel_24070/1249793878.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## 생각해보기
# - 학습 샘플 수가 작아지면 어떻게 되는가?

# %% [markdown]
# **나의 답변:**
# 샘플이 너무 적으면 몇 개 점에 직선이 맞춰져 참 관계(y = 3x + 2)를 못 찾고, 새 데이터에 대한 일반화가 나빠진다. 이번 실습도 샘플 5개만으로 참값 W=3, b=2 대신 W 약 7.28, b 약 -4.13이 나와 크게 어긋났다.

# %% [markdown]
# - 학습 샘플에 잡음이 많으면 어떻게 되는가? 이 경우 학습 데이터가 많이 필요한가?

# %% [markdown]
# **나의 답변:**
# 잡음이 크면 데이터가 참 직선 주변에 넓게 퍼져 MSE는 그 흩어진 점에 맞추려 하고, 이번처럼 손실이 약 301에서 멈추면 학습된 W, b가 참값과 멀어진다. 이 경우 학습 데이터를 많이 모아 잡음의 기댓값을 상쇄하는 것이 필요하다.
